# %% [markdown]
# At Aerofit, I have been tasked with the responsibility of analyzing
# the provided dataset to extract valuable insights and deliver actionable recommendations.
# Engaging in the resolution of this specific case study will aid in cultivating expertise in
# identifying connections between input variables and output variables.

# %%
# !gdown 1QUUVafPk09D4uy_O6zaaqhjN8obi5mTi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1QUUVafPk09D4uy_O6zaaqhjN8obi5mTi
# To: /content/aerofit_treadmill.txt
# 100% 7.28k/7.28k [00:00<00:00, 19.7MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#1. Importing the dataset and doing usual data analysis steps like checking the structure &
#characteristics of the dataset
# The data type of all columns in the “customers” table.

# %%
 dataT =pd.read_csv('aerofit_treadmill.txt')
 dataT
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ..     ...
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180
#
# [180 rows x 9 columns]

# %%
dataT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
dataT.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
dataT.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
dataT.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   KP781   40   Male         21        Single      6        5   83416
# 176   KP781   42   Male         18        Single      5        4   89641
# 177   KP781   45   Male         16        Single      5        5   90886
# 178   KP781   47   Male         18     Partnered      4        5  104581
# 179   KP781   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
dataT.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
# finding the number of rows and columns given in the dataset
dataT.shape
# Out:
# (180, 9)

# %%
dataT.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
#Checking for the missing values and find the number of missing values in each column
dataT.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
#2. Detect Outliers
#t○ Find the outliers for every continuous variable in the dataset

# %%
cv = dataT.dtypes[dataT.dtypes == 'int64'].reset_index()['index'].to_list()
for i in cv:
  sns.boxplot(dataT ,y = i )
  plt.show()

# %% [markdown]
# In this scenario of outlier:
#
# MILES:
# The majority of outlier are in the miles column, there are 50% people who walk around 65-125 miles. 25% of people walk very less , they cover around 25-75.
# and There are many outliers, few people cover huge miles .
#
# Age:
# 75% of customers aged between 20-33 are into fitness and uses the product, Only youth and early 30's are mainly focused according to the data. Few outlier that lies between 60-70. but such old age group people are very less.
#
# Fitness: 50% fitness level in people lies between 3 - 4 levels and 25% lies btween 2-3.
#
# Usage : Very few outliers who are majorly into fitness whose usage is high (6-7), but 75% people their usage lies between 2-4 , which is moderal. and 50% lies between 3-4 which is great.

# %%
#Remove/clip the data between the 5 percentile and 95 percentile
numerical_columns = dataT.select_dtypes(include=['int', 'float']).columns.to_list()
for i in numerical_columns:
  perc5= np.percentile(dataT[i], 5)
  perc95= np.percentile(dataT[i], 95)
  dataT[i] = np.clip(dataT[i], perc5, perc95)

# %%
#Checking if features like marital status, Gender, and age have any effect on the product purchased
##Finding if there is any relationship between the categorical variables and the output variable in the data.

sns.countplot(data = dataT, x = 'Product' , hue = 'MaritalStatus', color = 'violet')
plt.show()
# Out:
# <ipython-input-17-446617ee5fd8>:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:violet'` for the same effect.
#
#   sns.countplot(data = dataT, x = 'Product' , hue = 'MaritalStatus', color = 'violet')

# %% [markdown]
# Partners always prefer working together and fitness . So they are more likely to purchase or use the products. We can have offers and discounts for singles so that engage more

# %%
sns.countplot(data = dataT, x = 'Product' , hue = 'Gender', color = 'pink')
plt.show()
# Out:
# <ipython-input-18-3f948a84a959>:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:pink'` for the same effect.
#
#   sns.countplot(data = dataT, x = 'Product' , hue = 'Gender', color = 'pink')

# %% [markdown]
# According to my analysis We should get offers and discounts for single women / women so that they can use or purchase more specifically kp781.It is least likely. Males are moderately okay with every product there is no major difference .

# %%
#Finding if there is any relationship between the continuous variables and the output variable in the data.

# %%
Cont_var= dataT.select_dtypes(include=['int', 'float']).columns.to_list()
for i in Cont_var:
  sns.boxplot( data = dataT , x = 'Product' , y = dataT[i] , color = 'green')
  plt.show()

# %%
#4. Representing the Probability
# Finding the marginal probability (what percent of customers have purchased
#KP281, KP481, or KP781)

cross_tab = pd.crosstab(index=dataT['Product'],columns='count')
marginal_probability = cross_tab / cross_tab.sum()

print("Marginal Probability of Each Product:")
print(marginal_probability)
# Out:
# Marginal Probability of Each Product:
# col_0       count
# Product
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222

# %% [markdown]
# As the data that is being evaluated is , there are some issues with KP781 whose probablity is very less compared to other and to increase sales and usage we will have to either work for its price / usability or detect problems why it is least likely to be used by people specially females.

# %%
#Finding the probability that the customer buys a product based on each column.
cross_tab1 = pd.crosstab(index=dataT['Product'],columns=dataT['MaritalStatus'], normalize ='index')
cross_tab1
# Out:
# MaritalStatus  Partnered  Single
# Product
# KP281              0.600   0.400
# KP481              0.600   0.400
# KP781              0.575   0.425

# %% [markdown]
# Partners has more probablity ti use each product , as the data says all the 3 products has high possibility in couples than in singles.

# %%
cross_tab2 = pd.crosstab(index=dataT['Product'],columns=dataT['Gender'], normalize ='index')
cross_tab2
# Out:
# Gender     Female      Male
# Product
# KP281    0.500000  0.500000
# KP481    0.483333  0.516667
# KP781    0.175000  0.825000

# %%
#Finding the conditional probability that an event occurs given that another event has
#occurred. (Example: given that a customer is female, what is the probability
#she’ll purchase a KP481)

cross_tab3 = pd.crosstab(index=dataT['Gender'],columns=dataT['Product'], normalize ='index')
cross_tab3
# Out:
# Product     KP281     KP481     KP781
# Gender
# Female   0.526316  0.381579  0.092105
# Male     0.384615  0.298077  0.317308

# %% [markdown]
# Females and males are more likely to use KP281 , but females are very less likely to use or purchase KP781 but if we look at males they like KP281 more but also almost similar to use KP481 AND KP781

# %%
cross_tab4 = pd.crosstab(index=dataT['MaritalStatus'],columns=dataT['Product'], normalize ='index')
cross_tab4
# Out:
# Product           KP281     KP481     KP781
# MaritalStatus
# Partnered      0.448598  0.336449  0.214953
# Single         0.438356  0.328767  0.232877

# %% [markdown]
# Very slight difference between single and couples for the particular product kp281,They all like KP281. Th least liked product between singles and couples are KP781. no major differences between couple and single preferneces.

# %%
#5. Check the correlation among different factors
# Find the correlation between the given features in the table.

# %%
correlation_matrix = dataT.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot = True, cmap='coolwarm')
plt.title('Heatmap of Product Sales by Fitness')
plt.xlabel('Product')
plt.ylabel('Fitness')
plt.show()
# Out:
# <ipython-input-27-24db44028b09>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = dataT.corr()

# %% [markdown]
# Co-relation between variables:
#
# 1) Miles and fitness = highly co-related because the more miles a person walks more fitter they get.
#
# 2)Usage and miles = Highly co-realted as More they walk and cover large miles , more usgae of product is there.
#
# 3) Fitness and Usage = Moderately co -related with each other, More usage of product will lead to good level of fitness.
#
# 4)income and fitness = Moderately co -relative the more people earn or generate income, they invest more in fitness and better food.

# %%
# Customer profiling and recommendation
#Make customer profilings for each and every product.
kp281 = dataT[dataT['Product'] == 'KP281']

kp281[['Gender','MaritalStatus']].value_counts()
# Out:
# Gender  MaritalStatus
# Female  Partnered        27
# Male    Partnered        21
#         Single           19
# Female  Single           13
# dtype: int64

# %%
kp281 = dataT[dataT['Product'] == 'KP481']

kp281[['Gender','MaritalStatus']].value_counts()
# Out:
# Gender  MaritalStatus
# Male    Partnered        21
# Female  Partnered        15
#         Single           14
# Male    Single           10
# dtype: int64

# %%
kp281 = dataT[dataT['Product'] == 'KP781']
kp281[['Gender','MaritalStatus']].value_counts()
# Out:
# Gender  MaritalStatus
# Male    Partnered        19
#         Single           14
# Female  Partnered         4
#         Single            3
# dtype: int64

# %% [markdown]
# Analysis:
#
# Product 'KP281' is mostly preferred by 'couples' and if we specifically look at the gender then it mostly 'Female'. Couples are more into using this product!
#
# Product 'KP481' is majorly preferred by 'couples' again but if we specifically look at the gender then it mostly 'male'. Male gender prefers this product more and single males least like it.
#
# Product 'kp781' is already on the low side if we look at preference of people. in general it is preffered less than the other two produtcs . Females are least likely to use this product.
